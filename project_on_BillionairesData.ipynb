# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bd=pd.read_excel("D:\\.xlsx")

# %%
bd.head()
# Out:
#    rank  finalWorth               category                personName   age  \
# 0     1      211000       Fashion & Retail  Bernard Arnault & family  74.0
# 1     2      180000             Automotive                 Elon Musk  51.0
# 2     3      114000             Technology                Jeff Bezos  59.0
# 3     4      107000             Technology             Larry Ellison  78.0
# 4     5      106000  Finance & Investments            Warren Buffett  92.0
#
#          country    city              source             industries  \
# 0         France   Paris                LVMH       Fashion & Retail
# 1  United States  Austin       Tesla, SpaceX             Automotive
# 2  United States  Medina              Amazon             Technology
# 3  United States   Lanai              Oracle             Technology
# 4  United States   Omaha  Berkshire Hathaway  Finance & Investments
#
#   countryOfCitizenship  ... cpi_change_country           gdp_country  \
# ...

# %%
bd.columns
# Out:
# Index(['rank', 'finalWorth', 'category', 'personName', 'age', 'country',
#        'city', 'source', 'industries', 'countryOfCitizenship', 'organization',
#        'selfMade', 'status', 'gender', 'lastName', 'firstName', 'title',
#        'date', 'state', 'residenceStateRegion', 'birthYear', 'birthMonth',
#        'birthDay', 'cpi_country', 'cpi_change_country', 'gdp_country',
#        'gross_tertiary_education_enrollment',
#        'gross_primary_education_enrollment_country', 'life_expectancy_country',
#        'tax_revenue_country_country', 'total_tax_rate_country',
#        'population_country', 'latitude_country', 'longitude_country'],
#       dtype='object')

# %%
bdc=bd.copy()
bdc
# Out:
#       rank  finalWorth               category                personName   age  \
# 0        1      211000       Fashion & Retail  Bernard Arnault & family  74.0
# 1        2      180000             Automotive                 Elon Musk  51.0
# 2        3      114000             Technology                Jeff Bezos  59.0
# 3        4      107000             Technology             Larry Ellison  78.0
# 4        5      106000  Finance & Investments            Warren Buffett  92.0
# ...    ...         ...                    ...                       ...   ...
# 2635  2540        1000             Healthcare                   Yu Rong  51.0
# 2636  2540        1000        Food & Beverage    Richard Yuengling, Jr.  80.0
# 2637  2540        1000          Manufacturing             Zhang Gongyun  60.0
# 2638  2540        1000            Real Estate    Zhang Guiping & family  71.0
# 2639  2540        1000            Diversified               Inigo Zobel  66.0
#
# ...

# %%
bdc.shape
# Out:
# (2640, 34)

# %%
bdc.isnull().sum()
# Out:
# rank                                             0
# finalWorth                                       0
# category                                         0
# personName                                       0
# age                                             65
# country                                         38
# city                                            72
# source                                           0
# industries                                       0
# countryOfCitizenship                             0
# organization                                  2315
# selfMade                                         0
# status                                           0
# gender                                           0
# lastName                                         0
# firstName                                        3
# title                                         2301
# date                                             0
# ...

# %%
(bdc.isnull().sum()/bdc.shape[0])*100
# Out:
# rank                                           0.000000
# finalWorth                                     0.000000
# category                                       0.000000
# personName                                     0.000000
# age                                            2.462121
# country                                        1.439394
# city                                           2.727273
# source                                         0.000000
# industries                                     0.000000
# countryOfCitizenship                           0.000000
# organization                                  87.689394
# selfMade                                       0.000000
# status                                         0.000000
# gender                                         0.000000
# lastName                                       0.000000
# firstName                                      0.113636
# title                                         87.159091
# ...

# %%
bdc["personName"].nunique()
# Out:
# 2638

# %%
#  now i will be filling null values

# %%
bdc["age"]=bdc["age"].fillna(bdc["age"].median())
bdc
# Out:
#       rank  finalWorth               category                personName   age  \
# 0        1      211000       Fashion & Retail  Bernard Arnault & family  74.0
# 1        2      180000             Automotive                 Elon Musk  51.0
# 2        3      114000             Technology                Jeff Bezos  59.0
# 3        4      107000             Technology             Larry Ellison  78.0
# 4        5      106000  Finance & Investments            Warren Buffett  92.0
# ...    ...         ...                    ...                       ...   ...
# 2635  2540        1000             Healthcare                   Yu Rong  51.0
# 2636  2540        1000        Food & Beverage    Richard Yuengling, Jr.  80.0
# 2637  2540        1000          Manufacturing             Zhang Gongyun  60.0
# 2638  2540        1000            Real Estate    Zhang Guiping & family  71.0
# 2639  2540        1000            Diversified               Inigo Zobel  66.0
#
# ...

# %%
bdc.isnull().sum()
# Out:
# rank                                             0
# finalWorth                                       0
# category                                         0
# personName                                       0
# age                                              0
# country                                         38
# city                                            72
# source                                           0
# industries                                       0
# countryOfCitizenship                             0
# organization                                  2315
# selfMade                                         0
# status                                           0
# gender                                           0
# lastName                                         0
# firstName                                        3
# title                                         2301
# date                                             0
# ...

# %%
bdc["country"].nunique()
# Out:
# 78

# %%
bdc.loc[0:,["country","city",'countryOfCitizenship' ]]
# Out:
#             country        city countryOfCitizenship
# 0            France       Paris               France
# 1     United States      Austin        United States
# 2     United States      Medina        United States
# 3     United States       Lanai        United States
# 4     United States       Omaha        United States
# ...             ...         ...                  ...
# 2635          China    Shanghai                China
# 2636  United States  Pottsville        United States
# 2637          China       Gaomi                China
# 2638          China     Nanjing                China
# 2639    Philippines      Makati          Philippines
#
# [2640 rows x 3 columns]

# %%
bdc["country"].fillna(bdc['countryOfCitizenship'], inplace=True)

# %%
# bdc["country"]=bdc["country"].fillna(bdc['countryOfCitizenship'], inplace=True) dont use it like this other wise it will not work

# %%
bdc.isnull().sum()
# Out:
# rank                                             0
# finalWorth                                       0
# category                                         0
# personName                                       0
# age                                              0
# country                                          0
# city                                            72
# source                                           0
# industries                                       0
# countryOfCitizenship                             0
# organization                                  2315
# selfMade                                         0
# status                                           0
# gender                                           0
# lastName                                         0
# firstName                                        3
# title                                         2301
# date                                             0
# ...

# %%
bdc["city"].nunique()
# Out:
# 741

# %%
bdc.isnull().sum()
# Out:
# rank                                             0
# finalWorth                                       0
# category                                         0
# personName                                       0
# age                                              0
# country                                          0
# city                                            72
# source                                           0
# industries                                       0
# countryOfCitizenship                             0
# organization                                  2315
# selfMade                                         0
# status                                           0
# gender                                           0
# lastName                                         0
# firstName                                        3
# title                                         2301
# date                                             0
# ...

# %%
bdc=bdc.drop(["city"],axis=1)
bdc
# Out:
#       rank  finalWorth               category                personName   age  \
# 0        1      211000       Fashion & Retail  Bernard Arnault & family  74.0
# 1        2      180000             Automotive                 Elon Musk  51.0
# 2        3      114000             Technology                Jeff Bezos  59.0
# 3        4      107000             Technology             Larry Ellison  78.0
# 4        5      106000  Finance & Investments            Warren Buffett  92.0
# ...    ...         ...                    ...                       ...   ...
# 2635  2540        1000             Healthcare                   Yu Rong  51.0
# 2636  2540        1000        Food & Beverage    Richard Yuengling, Jr.  80.0
# 2637  2540        1000          Manufacturing             Zhang Gongyun  60.0
# 2638  2540        1000            Real Estate    Zhang Guiping & family  71.0
# 2639  2540        1000            Diversified               Inigo Zobel  66.0
#
# ...

# %%
bdc.isnull().sum()
# Out:
# rank                                             0
# finalWorth                                       0
# category                                         0
# personName                                       0
# age                                              0
# country                                          0
# source                                           0
# industries                                       0
# countryOfCitizenship                             0
# organization                                  2315
# selfMade                                         0
# status                                           0
# gender                                           0
# lastName                                         0
# firstName                                        3
# title                                         2301
# date                                             0
# state                                         1887
# ...

# %%
bdc
# Out:
#       rank  finalWorth               category                personName   age  \
# 0        1      211000       Fashion & Retail  Bernard Arnault & family  74.0
# 1        2      180000             Automotive                 Elon Musk  51.0
# 2        3      114000             Technology                Jeff Bezos  59.0
# 3        4      107000             Technology             Larry Ellison  78.0
# 4        5      106000  Finance & Investments            Warren Buffett  92.0
# ...    ...         ...                    ...                       ...   ...
# 2635  2540        1000             Healthcare                   Yu Rong  51.0
# 2636  2540        1000        Food & Beverage    Richard Yuengling, Jr.  80.0
# 2637  2540        1000          Manufacturing             Zhang Gongyun  60.0
# 2638  2540        1000            Real Estate    Zhang Guiping & family  71.0
# 2639  2540        1000            Diversified               Inigo Zobel  66.0
#
# ...

# %%
bdc["organization"].fillna("others", inplace=True)

# %%
bdc["organization"].nunique()
# Out:
# 295

# %%
bdc.loc[0:10,["firstName","lastName","title"]]
# Out:
#     firstName            lastName                 title
# 0     Bernard             Arnault      Chairman and CEO
# 1        Elon                Musk                   CEO
# 2        Jeff               Bezos  Chairman and Founder
# 3       Larry             Ellison       CTO and Founder
# 4      Warren             Buffett                   CEO
# 5        Bill               Gates               Cochair
# 6     Michael           Bloomberg                   CEO
# 7      Carlos           Slim Helu     Honorary Chairman
# 8      Mukesh              Ambani  Founder and Chairman
# 9       Steve             Ballmer                 Owner
# 10  Francoise  Bettencourt Meyers                   NaN

# %%
bdc["title"].nunique()
# Out:
# 97

# %%
bdc["title"]=bdc["title"].fillna(bdc["title"].mode()[0])

# %%
bdc.isnull().sum()
# Out:
# rank                                             0
# finalWorth                                       0
# category                                         0
# personName                                       0
# age                                              0
# country                                          0
# source                                           0
# industries                                       0
# countryOfCitizenship                             0
# organization                                     0
# selfMade                                         0
# status                                           0
# gender                                           0
# lastName                                         0
# firstName                                        3
# title                                            0
# date                                             0
# state                                         1887
# ...

# %%
bdc["residenceStateRegion"]=bdc["residenceStateRegion"].fillna(bdc["residenceStateRegion"].mode()[0])

# %%
bdc=bdc.drop(["state"],axis=1)

# %%
bdc["firstName"]=bdc["firstName"].fillna(bdc["firstName"].mode()[0])

# %%
bdc.isnull().sum()
# Out:
# rank                                            0
# finalWorth                                      0
# category                                        0
# personName                                      0
# age                                             0
# country                                         0
# source                                          0
# industries                                      0
# countryOfCitizenship                            0
# organization                                    0
# selfMade                                        0
# status                                          0
# gender                                          0
# lastName                                        0
# firstName                                       0
# title                                           0
# date                                            0
# residenceStateRegion                            0
# birthYear                                      76
# ...

# %%
bdc.columns
# Out:
# Index(['rank', 'finalWorth', 'category', 'personName', 'age', 'country',
#        'source', 'industries', 'countryOfCitizenship', 'organization',
#        'selfMade', 'status', 'gender', 'lastName', 'firstName', 'title',
#        'date', 'residenceStateRegion', 'birthYear', 'birthMonth', 'birthDay',
#        'cpi_country', 'cpi_change_country', 'gdp_country',
#        'gross_tertiary_education_enrollment',
#        'gross_primary_education_enrollment_country', 'life_expectancy_country',
#        'tax_revenue_country_country', 'total_tax_rate_country',
#        'population_country', 'latitude_country', 'longitude_country'],
#       dtype='object')

# %%
bdc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2640 entries, 0 to 2639
# Data columns (total 32 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   rank                                        2640 non-null   int64
#  1   finalWorth                                  2640 non-null   int64
#  2   category                                    2640 non-null   object
#  3   personName                                  2640 non-null   object
#  4   age                                         2640 non-null   float64
#  5   country                                     2640 non-null   object
#  6   source                                      2640 non-null   object
#  7   industries                                  2640 non-null   object
#  8   countryOfCitizenship                        2640 non-null   object
#  9   organization                                2640 non-null   object
# ...

# %% [markdown]
# ## Preparing Linear Regression model on Demographic Information y='finalWorth' x='gender', 'country', 'residenceStateRegion'

# %%
# turning categorical to dummy variable

# %%
bdc_encoded = pd.get_dummies(bdc, columns=['gender', 'residenceStateRegion','industries','selfMade','status','category','source','country',
                                          'organization','title'])

# %%
bdc_encoded.columns
# Out:
# Index(['rank', 'finalWorth', 'personName', 'age', 'countryOfCitizenship',
#        'lastName', 'firstName', 'date', 'birthYear', 'birthMonth',
#        ...
#        'title_President and Chairman', 'title_President and Founder',
#        'title_President and General Manager', 'title_Professor',
#        'title_Senior Advisor', 'title_Vice Chairman',
#        'title_Vice Chairman and Director',
#        'title_Vice President and Cofounder', 'title_former Chairman and CEO',
#        'title_owner and ceo'],
#       dtype='object', length=1441)

# %%
demographic_features =["age"]+["cpi_country"]+["cpi_change_country"]+[col for col in bdc_encoded.columns if col.startswith('gender_') or col.startswith('residenceStateRegion_')
                              or col.startswith('industries_')  or col.startswith('selfMade_')  or col.startswith('status_')
                                 or col.startswith('category_')or col.startswith('source_')or col.startswith('country_')
                              or col.startswith('organization_')or col.startswith('title_') ]
                                                                                                                                               
target = 'finalWorth'

# %%
# now i will split the data

# %%
from sklearn.model_selection import train_test_split

# %%
x = bdc_encoded[demographic_features]
y = bdc_encoded[target]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.28, random_state=42)
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
model = LinearRegression()
model.fit(x_train, y_train)


y_pred = model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(mse)
print(r2)
# Out:
# 3.245398730973956e+24
# -1.2116338597522104e+17

# %%
bdc.isnull().sum()
# Out:
# rank                                            0
# finalWorth                                      0
# category                                        0
# personName                                      0
# age                                             0
# country                                         0
# source                                          0
# industries                                      0
# countryOfCitizenship                            0
# organization                                    0
# selfMade                                        0
# status                                          0
# gender                                          0
# lastName                                        0
# firstName                                       0
# title                                           0
# date                                            0
# residenceStateRegion                            0
# birthYear                                      76
# ...

# %%
bdc["cpi_country"]=bdc["cpi_country"].fillna(bdc["cpi_country"].median())

# %%
bdc["cpi_change_country"]=bdc["cpi_change_country"].fillna(bdc["cpi_change_country"].median())

# %%
bdc=bdc.drop(["gross_tertiary_education_enrollment","gross_primary_education_enrollment_country","life_expectancy_country","tax_revenue_country_country",
              "total_tax_rate_country","population_country","latitude_country","longitude_country"],axis=1)

# %%
bdc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2640 entries, 0 to 2639
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   rank                  2640 non-null   int64
#  1   finalWorth            2640 non-null   int64
#  2   category              2640 non-null   object
#  3   personName            2640 non-null   object
#  4   age                   2640 non-null   float64
#  5   country               2640 non-null   object
#  6   source                2640 non-null   object
#  7   industries            2640 non-null   object
#  8   countryOfCitizenship  2640 non-null   object
#  9   organization          2640 non-null   object
#  10  selfMade              2640 non-null   bool
#  11  status                2640 non-null   object
#  12  gender                2640 non-null   object
#  13  lastName              2640 non-null   object
#  14  firstName             2640 non-null   object
# ...

# %%
bdc["gdp_country"]=bdc["gdp_country"].str.replace("$","").astype(str)
bdc["gdp_country"]=bdc["gdp_country"].str.replace(",","").astype(float)
# Out:
# C:\Users\duahu\AppData\Local\Temp\ipykernel_10316\1368505125.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   bdc["gdp_country"]=bdc["gdp_country"].str.replace("$","").astype(str)

# %%
bdc["gdp_country"]=bdc["gdp_country"].fillna(bdc["gdp_country"].median())

# %%
bdc.isnull().sum()
# Out:
# rank                     0
# finalWorth               0
# category                 0
# personName               0
# age                      0
# country                  0
# source                   0
# industries               0
# countryOfCitizenship     0
# organization             0
# selfMade                 0
# status                   0
# gender                   0
# lastName                 0
# firstName                0
# title                    0
# date                     0
# residenceStateRegion     0
# birthYear               76
# birthMonth              76
# birthDay                76
# cpi_country              0
# cpi_change_country       0
# gdp_country              0
# dtype: int64

# %% [markdown]
# # Demographic Analysis

# %% [markdown]
# # Top Billionaires

# %%
# Analyze the distribution of wealth among the top billionaires.
bdc.groupby(["personName","age"])[["finalWorth"]].sum().sort_values(by="finalWorth",ascending=False).head(10).plot(kind="bar",color="lightgreen",figsize=[10,5],label=True,title="Top 10 billionaires in the world")
# Out:
# <AxesSubplot: title={'center': 'Top 10 billionaires in the world'}, xlabel='personName,age'>

# %%
# Compare the net worth of individuals from different industries
bdc.groupby(["industries"])[["finalWorth"]].sum().plot(kind="bar",figsize=[10,5],color='lightgreen')
# Out:
# <AxesSubplot: xlabel='industries'>

# %%
##Country Wise Net worth of billionares

bdc.groupby(["country"])[["finalWorth"]].sum().sort_values(by="finalWorth",ascending=False).head(5)
# Out:
#                finalWorth
# country
# United States     4577000
# China             1805500
# India              637100
# France             501600
# Germany            496500

# %%
# Examine the dominant industries among the top billionaires.
bdc.groupby(["industries","personName"])[["finalWorth"]].sum().sort_values(by="finalWorth",ascending=False).head(10)
# Out:
#                                                  finalWorth
# industries            personName
# Fashion & Retail      Bernard Arnault & family       211000
# Automotive            Elon Musk                      180000
# Technology            Jeff Bezos                     114000
#                       Larry Ellison                  107000
# Finance & Investments Warren Buffett                 106000
# Technology            Bill Gates                     104000
# Media & Entertainment Michael Bloomberg               94500
# Telecom               Carlos Slim Helu & family       93000
# Diversified           Mukesh Ambani                   83400
# Technology            Steve Ballmer                   80700

# %%
# From which country and which industry Final worth of top billionare is high

bdc.groupby(["industries","country"])[["finalWorth"]].sum().sort_values(by="finalWorth",ascending=False).head(20).plot(kind="bar",figsize=[10,5],color='lightgreen')
# Out:
# <AxesSubplot: xlabel='industries,country'>

# %% [markdown]
# #### Converting my data to excel format

# %%
try:
    with pd.ExcelWriter('output.xlsx') as writer:
        bdc.to_excel(writer, sheet_name='Sheet1', index=True)

except Exception as e:
    print("exception occured")

# %%
with pd.ExcelWriter("output.xlsx", engine="xlsxwriter") as writer:
    bdc.to_excel(writer, sheet_name="Sheet1", index=False)

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\duahu

# %%
with pd.ExcelWriter('D:\.xlsx', engine='xlsxwriter') as writer:
    bdc.to_excel(writer, sheet_name='Sheet1', index=False)
